# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/microsoft/computervision-recipes.git
# Out:
# Cloning into 'computervision-recipes'...
# remote: Enumerating objects: 6125, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 6125 (delta 224), reused 215 (delta 202), pack-reused 5830
# Receiving objects: 100% (6125/6125), 258.94 MiB | 22.68 MiB/s, done.
# Resolving deltas: 100% (3822/3822), done.

# %%
cd computervision-recipes/
# Out:
# /content/computervision-recipes

# %%
# !cp -r /content/drive/MyDrive/DangerousDrivingRecognition/backup ..

# %%
ls
# Out:
# AUTHORS.md    CONTRIBUTING.md  LICENSE         README.md    setup.py
# checkpoints/  data/            MANIFEST.in     scenarios/   tests/
# _config.yml   docker/          NOTICE.txt      SECURITY.md  utils_cv/
# contrib/      environment.yml  pyproject.toml  SETUP.md

# %%
import os

classes = os.listdir("/content/backup")
for cls in classes:
  videos = os.listdir(f"/content/backup/{cls}")
  for video in videos:
    name = video.split(".")[0]
    os.replace(f"/content/backup/{cls}/{video}",
              f"/content/backup/{cls}/{name}.mp4")

# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Action Recognition Model
#
# In this notebook, we show how to finetune the pretrained R(2+1)D model. For this notebook, we'll be using a dataset that we created to demonstrate how to load, fine-tune, and evaluate and action recognition model.

# %% [markdown]
# ### Initialization
# Import all the functions we need.

# %%
# !pip install scrapbook
# !pip install decord
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scrapbook in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from scrapbook) (7.9.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from scrapbook) (1.3.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from scrapbook) (6.0.1)
# Requirement already satisfied: papermill in /usr/local/lib/python3.7/dist-packages (from scrapbook) (2.4.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from scrapbook) (4.3.3)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (5.3.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (57.4.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython->scrapbook) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->scrapbook) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->scrapbook) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->scrapbook) (0.2.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->scrapbook) (0.18.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema->scrapbook) (4.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->scrapbook) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->scrapbook) (22.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->scrapbook) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->scrapbook) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->scrapbook) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->scrapbook) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->scrapbook) (2022.2.1)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (7.1.2)
# Requirement already satisfied: nbformat>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (5.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (2.23.0)
# Requirement already satisfied: ansiwrap in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (0.8.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (0.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (8.0.1)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (0.6.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from papermill->scrapbook) (6.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.2.0->papermill->scrapbook) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.5 in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.2.0->papermill->scrapbook) (6.1.12)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill->scrapbook) (23.2.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill->scrapbook) (5.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill->scrapbook) (4.11.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.1.2->papermill->scrapbook) (2.16.1)
# Requirement already satisfied: textwrap3>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from ansiwrap->papermill->scrapbook) (0.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->scrapbook) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->papermill->scrapbook) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->papermill->scrapbook) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->papermill->scrapbook) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->papermill->scrapbook) (3.0.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: decord in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from decord) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: einops in /usr/local/lib/python3.7/dist-packages (0.4.1)

# %%
import sys

sys.path.append("../../")

import numpy as np
import os
from pathlib import Path
import time
import warnings

from sklearn.metrics import accuracy_score
import scrapbook as sb
import torch
import torchvision

from utils_cv.action_recognition.data import Urls
from utils_cv.action_recognition.dataset import VideoDataset
from utils_cv.action_recognition.model import VideoLearner 
from utils_cv.common.gpu import system_info
from utils_cv.common.data import data_path, unzip_url

system_info()
warnings.filterwarnings('ignore')
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
#
# PyTorch 1.12.1+cu113
#
# Torch-vision 0.13.1+cu113
#
# Available devices:
# CPUs only, no GPUs found

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
# Your data
# DATA_PATH = unzip_url(Urls.milk_bottle_action_path, exist_ok=True)
DATA_PATH = "../backup"

# Number of consecutive frames used as input to the DNN. Use: 32 for high accuracy, 8 for inference speed.
MODEL_INPUT_SIZE = 8

# Number of training epochs
EPOCHS = 16

# Batch size. Reduce if running out of memory.
BATCH_SIZE = 8

# Learning rate
LR = 0.0001

# %% [markdown]
# ---
# # Prepare Action Recognition Dataset
#
# In this notebook, we use a toy dataset called *Milk Bottle Actions*, which consists of 60 clips of 2 actions: `{opening, pouring}`. The same objects appear in both classes.
#
# After downloading the dataset, the `unzip_url` helper function will also unzip the dataset to the `data` directory.

# %%
os.listdir(Path(DATA_PATH))
# Out:
# ['Dangerous', 'Safe']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/pouring`
# - `/opening`
#
# Action videos can be stored as follows:
#
# ```
# /data
# +-- action_class_1
# |   +-- video_01.mp4
# |   +-- video_02.mp4
# |   +-- ...
# +-- action_class_2
# |   +-- video_11.mp4
# |   +-- video_12.mp4
# |   +-- ...
# +-- ...
# ```
#
# For action recognition, the way data is stored can be as straight forward as putting the videos for each action inside a folder named after the action.

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a VideoDataset object using the `VideoDataset` helper class. This class knows how to extract the dataset based on the above format. We simply pass it the path to the root dir of our dataset.

# %%
data = VideoDataset(DATA_PATH, batch_size=BATCH_SIZE, sample_length=MODEL_INPUT_SIZE)

# %% [markdown]
# The `VideoDataset` will automatically divide the data into a training/validation set and set up the dataloaders that PyTorch uses. Lets inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \
    \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 415 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7efe3299e450>
# Testing dataset: 138 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7efdab22f890>

# %% [markdown]
# Lets take a look at the data by briefly looking at the frames.

# %%
data.show_batch(rows=5, train_or_test="test")

# %% [markdown]
# # Finetune a Pretrained Model
#
# By default, our VideoLearner's R(2+1)D model is pretrained on __ig65m__ which is based of 65 million instagram videos. You can find more information on the dataset in this paper: https://arxiv.org/pdf/1905.00561.pdf
#
# When we initialize the VideoLearner, we simply pass in the dataset. By default, the object will set the model to torchvision's ig65m R(2+1)D pre-trained model. Alternatively, we can also select the R(2+1)D model pretrained on the __kinetics__ dataset or even pass in the model we want to use.

# %%
learner = VideoLearner(data, num_classes=2)
# Out:
# Loading r2plus1d_34_8_ig65m model
# Using cache found in /root/.cache/torch/hub/moabitcoin_ig65m-pytorch_master

# %% [markdown]
# The dataset we're using only has two actions: __opening__ and __pouring__. This means that our fully connected (FC) layer must only have an output of two. We can check that this is the case by inspecting the model's FC layer.

# %%
learner.model.fc
# Out:
# Linear(in_features=512, out_features=2, bias=True)

# %% [markdown]
# Fine-tune the model using the `learner`'s `fit` function. Here we pass in the learning rate.

# %%
learner.fit(lr=LR, epochs=EPOCHS)
# Out:
# Params to learn:
# 	full network
# Epoch 1 =========================================================
# lr=[0.0001]
# tensor([4.])
# tensor([[False,  True, False, False,  True,  True, False,  True],
#         [ True, False,  True,  True, False, False,  True, False]])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-c1de2e68eb4d> in <module>
# ----> 1 learner.fit(lr=LR, epochs=EPOCHS)
#
# /content/computervision-recipes/utils_cv/action_recognition/model.py in fit(self, lr, epochs, model_dir, model_name, momentum, weight_decay, mixed_prec, use_one_cycle_policy, warmup_pct, lr_gamma, lr_step_size, grad_steps, save_model)
#     264                     grad_steps=grad_steps,
#     265                     mixed_prec=mixed_prec,
# --> 266                     topk=topk,
#     267                 )
#     268             )
#
# /content/computervision-recipes/utils_cv/action_recognition/model.py in train_an_epoch(model, data_loaders, device, criterion, optimizer, grad_steps, mixed_prec, topk)
#     352
#     353                     # measure accuracy and record loss
# --> 354                     prec1, prec5 = accuracy(outputs, target, topk=(1, topk))
#     355
#     356                     losses.update(loss.item(), inputs.size(0))
#
# /content/computervision-recipes/utils_cv/action_recognition/references/metrics.py in accuracy(output, target, topk)
#      35         res = []
#      36         for k in topk:
# ---> 37             print(correct[:k].view(-1).float().sum(0, keepdim=True))
#      38             print(correct)
#      39             correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
#
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %% [markdown]
# # Evaluate
#
# Video datasets, composed of multiple videos, have varying video lengths. Yet our model only takes in clips of a set length. This is why we need to take into consideration two types of accuracies when evaluating our model: clip-level accuracy and video-level accuracy.
#
# Our classifications are set at the video level, which mean that each video is assigned 1 classification. However, each video could have hundreds or thousands of frames. To make sure we're getting a good range of clips across those frames, we can sample a single video (uniformly) a bunch of times. By default, our evaluation tool will sample 10 clips uniformly from each test video and pass it into the model in batches of [10 x 3 x (8 or 32) x 112 x 112]. This is where clip-level accuracy comes in. The direct results of the model will show us how many of those clips are correctly classified.
#
# Since our classifications are at the video level, we'll also want to see what our video-level accuracy is. We do this simply by average across the clip-level accuracy for each video.

# %%
ret = learner.evaluate()
# Out:
# 15 samples of torch.Size([3, 8, 112, 112])
# Avg. inference time per video (15 clips) = 993.07 ms
# Video prediction accuracy = 1.0
# Clip prediction accuracy = 0.75

# %% [markdown]
# # Predict
#
# Now that we've developed a model that works, lets run a prediction on one of our videos and see how it works. We'll choose an image that's already downloaded to our disk, and run it through our `predict_video()` function.

# %%
test_vid = str(data_path()/"milkBottleActions"/"opening"/"01.mp4")

# %%
learner.predict_video(test_vid)
# Out:
# Total frames = 195
# 8.0 fps<p style='font-size:20px'>opening (0.678)</p>

# %% [markdown]
# # Conclusion
# Using the concepts introduced in this notebook, you can bring your own dataset and train an action recognition model to detect specific objects of interest for your scenarios.

# %%
# Preserve some of the notebook outputs
sb.glue("vid_pred_accuracy", accuracy_score(ret["video_trues"], ret["video_preds"]))
sb.glue("clip_pred_accuracy", accuracy_score(ret["clip_trues"], ret["clip_preds"]))
